# %%
fname="Appendix_14_cancer"

# %%
# %%bash -s $fname
# cat<<EOF >$1.tex
# \documentclass[11pt]{article}
# \usepackage[paperheight=190mm,paperwidth=180mm]{geometry}
#  \geometry{
#  left=5mm,
#  right=5mm,
#  top=5mm,
#  bottom=5mm,
#  }
#
# \usepackage[labelfont=bf]{caption}
# \usepackage{multirow}
# \usepackage[rgb]{xcolor}
# \usepackage{fontspec}
# \usepackage[utf8]{inputenc}
# \usepackage[T1]{fontenc}
# \usepackage{graphicx}
# \begin{document}
# \setmainfont{Arial}
#
# \definecolor{Blue}{RGB}{50, 49, 145}
#
# \noindent
# \scriptsize
#
#
# \raggedright \begin{minipage}[!ht]{0.5\textwidth}
# \raggedright \textbf{A} \textcolor{Blue}{Overview of the methodology}
# \includegraphics[width=1\textwidth]{overview.pdf}
# \raggedright \textbf{B} \textcolor{Blue}{Mapping on NF bulk data}
# \includegraphics[width=1\textwidth]{NF/figures/overview.pdf}
# \end{minipage}\hfill
# \begin{minipage}[!ht]{0.5\textwidth}
# \raggedright \textbf{C} \textcolor{Blue}{Mapping on Human Melanoma scRNAseq data}
# \includegraphics[width=1\textwidth]{Melanoma/figures/overview.pdf}
# \end{minipage}\hfill
#
#
#
# \begin{minipage}[!ht]{0.5\textwidth}
# \raggedright \textbf{D} \textcolor{Blue}{Mapping on Neuroblastoma patient T40}
# \includegraphics[width=1\textwidth]{Neuroblastoma/figures/T40.pdf}
# \end{minipage}\hfill
# \begin{minipage}[!ht]{0.5\textwidth}
# \raggedright \textbf{E} \textcolor{Blue}{Mapping on Neuroblastoma patient T92}
# \includegraphics[width=1\textwidth]{Neuroblastoma/figures/T92.pdf}
# \end{minipage}\hfill
#
# \hfill
# \clearpage
#
#
# EOF
#
# echo "\end{document}" >> $1.tex
#
# xelatex --shell-escape $1.tex
# rm $1.tex
# convert -flatten -density 300 $1.pdf $1.jpg
# identify $1.pdf
# Out:
# This is XeTeX, Version 3.14159265-2.6-0.999991 (TeX Live 2019/Debian) (preloaded format=xelatex)
#  \write18 enabled.
# entering extended mode
# (./fig_cancer.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size11.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/caption/caption.sty
# (/usr/share/texlive/texmf-dist/tex/latex/caption/caption3.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/multirow/multirow.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# ...

# %%
from IPython.display import Image
Image(filename=fname+'.jpg')

# %%
fname="Appendix_15_cancer"

# %%
# %%bash -s $fname
# cat<<EOF >$1.tex
# \documentclass[11pt]{article}
# \usepackage[paperheight=211mm,paperwidth=180mm]{geometry}
#  \geometry{
#  left=5mm,
#  right=5mm,
#  top=5mm,
#  bottom=5mm,
#  }
#
# \usepackage[labelfont=bf]{caption}
# \usepackage{multirow}
# \usepackage[rgb]{xcolor}
# \usepackage{fontspec}
# \usepackage[utf8]{inputenc}
# \usepackage[T1]{fontenc}
# \usepackage{graphicx}
# \begin{document}
# \setmainfont{Arial}
#
# \definecolor{Blue}{RGB}{50, 49, 145}
#
# \noindent
# \scriptsize
#
#
# \raggedright \textbf{A} \textcolor{Blue}{Focus on a specific melanoma patient}
# \includegraphics[width=1\textwidth]{Melanoma/figures/suppfig.pdf}
#
# \raggedright \textbf{B} \textcolor{Blue}{Patient selection for neuroblastoma}
# \includegraphics[width=1\textwidth]{Neuroblastoma/figures/suppfig.pdf}
#
# \raggedright \textbf{C} \textcolor{Blue}{Projection of neuroblastoma patients with annotations}
#
# \begin{minipage}[!ht]{0.24\textwidth}
# \includegraphics[width=1\textwidth]{Neuroblastoma/figures/T75-2.pdf}
# \end{minipage}\hfill
# \begin{minipage}[!ht]{0.24\textwidth}
# \includegraphics[width=1\textwidth]{Neuroblastoma/figures/T10-2.pdf}
# \end{minipage}\hfill
# \begin{minipage}[!ht]{0.24\textwidth}
# \includegraphics[width=1\textwidth]{Neuroblastoma/figures/T19-2.pdf}
# \end{minipage}\hfill
# \begin{minipage}[!ht]{0.24\textwidth}
# \includegraphics[width=1\textwidth]{Neuroblastoma/figures/T34-2.pdf}
# \end{minipage}\hfill
#
# \begin{minipage}[!ht]{0.24\textwidth}
# \includegraphics[width=1\textwidth]{Neuroblastoma/figures/T40-2.pdf}
# \end{minipage}\hfill
# \begin{minipage}[!ht]{0.24\textwidth}
# \includegraphics[width=1\textwidth]{Neuroblastoma/figures/T71-2.pdf}
# \end{minipage}\hfill
# \begin{minipage}[!ht]{0.24\textwidth}
# \includegraphics[width=1\textwidth]{Neuroblastoma/figures/T92-2.pdf}
# \end{minipage}\hfill
# \begin{minipage}[!ht]{0.24\textwidth}
# \includegraphics[width=1\textwidth]{Neuroblastoma/figures/T27-2.pdf}
# \end{minipage}\hfill
# \hfill
# \clearpage
#
#
# EOF
#
# echo "\end{document}" >> $1.tex
#
# xelatex --shell-escape $1.tex
# rm $1.tex
# convert -flatten -density 300 $1.pdf $1.jpg
# identify $1.pdf
# Out:
# This is XeTeX, Version 3.14159265-2.6-0.999991 (TeX Live 2019/Debian) (preloaded format=xelatex)
#  \write18 enabled.
# entering extended mode
# (./suppfig_cancer.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size11.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/caption/caption.sty
# (/usr/share/texlive/texmf-dist/tex/latex/caption/caption3.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/multirow/multirow.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# ...

# %%
from IPython.display import Image
Image(filename=fname+'.jpg')
